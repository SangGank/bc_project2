# %%
import pandas as pd

# %%
import json

with open("../data/dataset/test/klue-re-v1.1_dev.json", "r") as f:
	data = json.load(f)
    
# print(data)

# %%
len(data)
# Out:
# 7765

# %%
dev = pd.read_csv('../data/dataset/test/test_data.csv')

# %%
dev
# Out:
#         id                                           sentence  \
# 0        0               지난 15일 MBC '탐사기획 스트레이트'가 이 사실을 보도했다.
# 1        1  사랑스러운 ‘프린세스 프링’의 이름은 봄의 공주님: Princess(s)Pring이...
# 2        2  한편, 본인(이근안)을 모델로 한 MBC 특집드라마 가 1995년 6.25 특집극으...
# 3        3  정창손은 김질과 같이 대궐로 달려가 고변하며 '신은 실로 모르고 김질만 혼자 참여하...
# 4        4  당시 민주당 이진련 시의원은 권영진 시장에게 "긴급 생계자금을 왜 현금으로 지원하지...
# ...    ...                                                ...
# 7760  7760  코로나19 방역 조치의 일환으로 국민의 움직임을 통제하려는 정부의 시도를 이탈리아 ...
# 7761  7761  선 연구원은 “위식도역류질환치료제인 케이캡이 92억원 판매되면서 2019년 연간 3...
# 7762  7762  한국전기안전공사(사장 조성완)는 8월 1일부로, 3급 간부직원에 대한 승진·이동 인...
# 7763  7763             1987년 B. 슈나이더(B. Schneider)에 의해 만들어졌다.
# 7764  7764  이승옥 강진군수는 2일 NH농협은행 강진군지부(지부장 강대형)를 방문해 부품·소재·...
#
#                                          subject_entity  \
# 0     {'word': 'MBC', 'start_idx': 7, 'end_idx': 9, ...
# 1     {'word': '프린세스 프링', 'start_idx': 7, 'end_idx':...
# ...

# %%
dev['subject_entity'] = dev['subject_entity'].astype(str)
dev['object_entity'] = dev['object_entity'].astype(str)
data['subject_entity'] = data['subject_entity'].astype(str)
data['object_entity'] = data['object_entity'].astype(str)

# %%
dev.dtypes
# Out:
# id                 int64
# sentence          object
# subject_entity    object
# object_entity     object
# label              int64
# source            object
# dtype: object

# %%
type(dev['sentence'].iloc[0])
# Out:
# str

# %%
data = pd.DataFrame(data)
data
# Out:
#                       guid                                           sentence  \
# 0     klue-re-v1_dev_00000  20대 남성 A(26)씨가 아버지 치료비를 위해 B(30)씨가 모아둔 돈을 훔쳐 인...
# 1     klue-re-v1_dev_00001  그러나 심 의원은 보좌진이 접속 권한을 받아 정부 업무추진비 사용 내역 등을 다운받...
# 2     klue-re-v1_dev_00002  영화 《룸》에서 감금되어 살아가는 여자의 아들 '잭' 역으로 주목받으며, 크리틱스 ...
# 3     klue-re-v1_dev_00003  전라남도(도지사 김영록)는 해양수산부의 2020년 어촌뉴딜300 공모사업에 15개 ...
# 4     klue-re-v1_dev_00004  부산항만공사(BPA, 사장 남기찬)는 27일 아동의 인권존중과 아동학대 예방에 대한...
# ...                    ...                                                ...
# 7760  klue-re-v1_dev_07760  제작진이 그렇다고 하자 사장님은 "그러니깐 그렇다. 백 대표 음식들이 맛이 다 강하...
# 7761  klue-re-v1_dev_07761  청 왕조의 가법(家法)에 따르면 동치제가 죽었을 때, 항렬이 부(溥)자인 후손들이 ...
# 7762  klue-re-v1_dev_07762  그러므로 동전의 변덕스러운 회전들은 2명의 예민한 거인 - 7 승 0 패의 올라주원...
# 7763  klue-re-v1_dev_07763  한편, (재)광양시어린이보육재단은 2017년 7월 출범하여 △광양형 0세 어린이집,...
# 7764  klue-re-v1_dev_07764  그러나 당은 태종에 치세에 이르자 강성해졌고, 이에 따라 중국 중심의 세계를 재형성...
#
# ...

# %%
data.dtypes
# Out:
# guid              object
# sentence          object
# subject_entity    object
# object_entity     object
# label             object
# source            object
# dtype: object

# %%
result = pd.merge(left = dev[['id','sentence','subject_entity','object_entity']], right = data.loc[:, 'sentence':], on = ['sentence','subject_entity','object_entity'])
result
# Out:
#         id                                           sentence  \
# 0        0               지난 15일 MBC '탐사기획 스트레이트'가 이 사실을 보도했다.
# 1        1  사랑스러운 ‘프린세스 프링’의 이름은 봄의 공주님: Princess(s)Pring이...
# 2        2  한편, 본인(이근안)을 모델로 한 MBC 특집드라마 가 1995년 6.25 특집극으...
# 3        3  정창손은 김질과 같이 대궐로 달려가 고변하며 '신은 실로 모르고 김질만 혼자 참여하...
# 4        4  당시 민주당 이진련 시의원은 권영진 시장에게 "긴급 생계자금을 왜 현금으로 지원하지...
# ...    ...                                                ...
# 7760  7760  코로나19 방역 조치의 일환으로 국민의 움직임을 통제하려는 정부의 시도를 이탈리아 ...
# 7761  7761  선 연구원은 “위식도역류질환치료제인 케이캡이 92억원 판매되면서 2019년 연간 3...
# 7762  7762  한국전기안전공사(사장 조성완)는 8월 1일부로, 3급 간부직원에 대한 승진·이동 인...
# 7763  7763             1987년 B. 슈나이더(B. Schneider)에 의해 만들어졌다.
# 7764  7764  이승옥 강진군수는 2일 NH농협은행 강진군지부(지부장 강대형)를 방문해 부품·소재·...
#
#                                          subject_entity  \
# 0     {'word': 'MBC', 'start_idx': 7, 'end_idx': 9, ...
# 1     {'word': '프린세스 프링', 'start_idx': 7, 'end_idx':...
# ...

# %%
result.to_csv('../data/dataset/test/dev_final.csv')

# %%
train = pd.read_csv('../data/dataset/train/train2.csv')
train[train['label']=='no_relation']
# Out:
#        Unnamed: 0     id                                           sentence  \
# 0               0      0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1               1      1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 4               4      4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# 6               6      6  그에 따라 나폴리와 계약을 연장한 마라도나는 1989년 팀을 UEFA컵 정상으로 인...
# 14             14     14  조토 디 본도네, 마사초, 피에로 델라 프란체스카, 도메니코 기를란다요, 페루지노,...
# ...           ...    ...                                                ...
# 32047       32047  32047  21일 정읍시에 따르면 올해 노후 경유차 조기 폐차 지원사업으로 예산 17억6880...
# 32049       32049  32049  메이저 리그 10승 경력을 높이 사서, 2011년 12월 2일 삼성 라이온즈에 영입...
# 32050       32050  32050  위광환 전라남도 해양수산국장은 “지난 3차례 스마트양식 클러스터 조성 공모를 통해 ...
# 32052       32052  32052  심지어 전용 연습구장도 없어 훈련을 여러 지역을 돌아다니며 해야 할 정도로 팀 사정...
# 32058       32058  32058  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
#
# ...
